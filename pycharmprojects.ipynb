# %%
#2
task2=lambda s: "" .join(
    filter(
        lambda w:len(w)%2==0,
        map(
            lambda w: w[::-1],
            filter(lambda w: not any(c.isdigit() for c in w),s.split())
        )
    )
)
print(task2("arulljdjnxh"))

# %%
import os

print(os.getcwd())
# Out:
# /Users/aruzhan

# %%
import os

os.listdir("/Users/aruzhan")
# Out:
# ['Untitled10.ipynb',
#  'Untitled7.ipynb',
#  '.config',
#  'Music',
#  'Untitled12.ipynb',
#  'Untitled5.ipynb',
#  'Untitled1.ipynb',
#  'Zhakupova Adia 2 week.ipynb',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  'Daniyarbek Aruzhan week3',
#  '.xonshrc',
#  'Untitled3.ipynb',
#  'Untitled.ipynb',
#  '.zshrc',
#  'Untitled4.ipynb',
#  'Untitled6.ipynb',
#  'AruzhanDaniyarbek7week.ipynb',
#  'Pictures',
#  'Untitled11.ipynb',
#  '.zsh_history',
#  'Untitled2.ipynb',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  '.lesshst',
#  'untitled.txt',
#  'Public',
#  '.tcshrc',
#  'Untitled8.ipynb',
#  'Movies',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'Documents',
#  '.vscode',
#  '.bash_profile',
#  'Downloads',
#  '.gitconfig',
#  'Untitled9.ipynb',
#  'pycharmprojects.ipynb',
#  'data.txt',
#  '.viminfo',
#  '.zsh_sessions',
#  '.conda',
#  'PyCharmMiscProject']

# %%
import csv

with open("employees.csv", "r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        print(row)
# Out:
# {'name': 'Ali', 'department': 'IT', 'salary': '500000'}
# {'name': 'Dana', 'department': 'HR', 'salary': '300000'}
# {'name': 'Arman', 'department': 'IT', 'salary': '600000'}
# {'name': 'Aruzhan', 'department': 'Marketing', 'salary': '400000'}
# {'name': 'Dias', 'department': 'IT', 'salary': '450000'}
